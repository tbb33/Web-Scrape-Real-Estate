# %%
#some websites need to see some browser headers to allow scripts to scrape them.

headers = {
    'pragma': 'no-cache',
    'cache-control': 'no-cache',
    'dnt': '1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (X11; CrOS x86_64 8172.45.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.64 Safari/537.36',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8',
}

# %%
import requests
from bs4 import BeautifulSoup

r=requests.get("https://pythonizing.github.io/data/real-estate/rock-springs-wy/LCWYROCKSPRINGS/")
c=r.content

soup=BeautifulSoup(c,"html.parser")

#get all property listings
all=soup.find_all("div", {"class":"propertyRow"}) #tag=div, class=propertyRow

#extract price from first property in all
#all[0].find_all("h4", {"class":"propPrice"}) #output has tags
#all[0].find("h4", {"class":"propPrice"}).text #output has \n
#all[0].find("h4", {"class":"propPrice"}).text.replace('\n',"") #output has spaces
all[0].find("h4", {"class":"propPrice"}).text.replace('\n',"").replace(" ","")
# Out:
# '$725,000'

# %%
for item in all:
    print(item.find("h4", {"class":"propPrice"}).text.replace('\n',"").replace(" ",""))
# Out:
# $725,000
# $452,900
# $396,900
# $389,900
# $254,000
# $252,900
# $210,000
# $209,000
# $199,900
# $196,900

# %%
#all addresses
for item in all:
    print(item.find("span",{"class":"propAddressCollapse"}).text) #NOTICE ALL[VAR]=ITEM
# Out:
# 0 Gateway
# 1003 Winchester Blvd.
# 600 Talladega
# 3239 Spearhead Way
# 522 Emerald Street
# 1302 Veteran's Drive
# 1021 Cypress Cir
# 913 Madison Dr
# 1344 Teton Street
# 4 Minnies Lane

# %%
for item in all:
    print(item.find("h4", {"class":"propPrice"}).text.replace('\n',"").replace(" ",""))
    print(item.find_all("span",{"class":"propAddressCollapse"})[0].text) #1st ele, text
    print(item.find_all("span",{"class":"propAddressCollapse"})[1].text)
    print(" ") #spacing
# Out:
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
#
# $196,900
# 4 Minnies Lane
# Rock Springs, WY 82901

# %%
#nbr bed/bath; mytry
all[1].find("span",{"class":"infoBed"}).text.replace(" Full Beds","")
all[1].find("span",{"class":"infoValueFullBath"}).text.replace(" Full Baths","")

for item in all:
    print(item.find("h4", {"class":"propPrice"}).text.replace('\n',"").replace(" ",""))
    print(item.find_all("span",{"class":"propAddressCollapse"})[0].text) #1st ele, text
    print(item.find_all("span",{"class":"propAddressCollapse"})[1].text)
    try:
        print(item.find("span",{"class":"infoBed"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoValueFullBath"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoSqFt"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoValueHalfBath"}).find("b").text)
    except:
        print(None)
    print(" ") #spacing
# Out:
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
# None
# None
# None
# None
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
# 4
# 4
# None
# None
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
# 5
# 3
# 3,154
# None
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
# 4
# 3
# 3,076
# 1
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
# 3
# 3
# 1,172
# None
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
# 4
# 2
# 1,932
# None
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
# 4
# 3
# 1,676
# None
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
# 3
# 2
# 1,344
# None
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
# 3
# 2
# 1,920
# None
#
# $196,900
# 4 Minnies Lane
# Rock Springs, WY 82901
# 3
# 2
# 1,664
# None

# %%
#lot size
for item in all:
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}), 
                                               column_group.find_all("span",{"class":"featureName"})):
            if "Lot Size" in feature_group.text:
                print(feature_name.text)
# Out:
# 0.21 Acres
# Under 1/2 Acre,
# Under 1/2 Acre,
# 0.27 Acres
# Under 1/2 Acre,
# Under 1/2 Acre,
# Under 1/2 Acre,
# 2.02 Acres

# %%
#adding lot size
all[1].find("span",{"class":"infoBed"}).text.replace(" Full Beds","")
all[1].find("span",{"class":"infoValueFullBath"}).text.replace(" Full Baths","")

for item in all:
    print(item.find("h4", {"class":"propPrice"}).text.replace('\n',"").replace(" ",""))
    print(item.find_all("span",{"class":"propAddressCollapse"})[0].text) #1st ele, text
    print(item.find_all("span",{"class":"propAddressCollapse"})[1].text)
    try:
        print(item.find("span",{"class":"infoBed"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoValueFullBath"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoSqFt"}).find("b").text)
    except:
        print(None)
    try:
        print(item.find("span",{"class":"infoValueHalfBath"}).find("b").text)
    except:
        print(None)
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}), 
                                               column_group.find_all("span",{"class":"featureName"})):
            if "Lot Size" in feature_group.text:
                print(feature_name.text)
    
    print(" ") #spacing
# Out:
# $725,000
# 0 Gateway
# Rock Springs, WY 82901
# None
# None
# None
# None
#
# $452,900
# 1003 Winchester Blvd.
# Rock Springs, WY 82901
# 4
# 4
# None
# None
# 0.21 Acres
#
# $396,900
# 600 Talladega
# Rock Springs, WY 82901
# 5
# 3
# 3,154
# None
#
# $389,900
# 3239 Spearhead Way
# Rock Springs, WY 82901
# 4
# 3
# 3,076
# 1
# Under 1/2 Acre,
#
# $254,000
# 522 Emerald Street
# Rock Springs, WY 82901
# 3
# 3
# 1,172
# None
# Under 1/2 Acre,
#
# $252,900
# 1302 Veteran's Drive
# Rock Springs, WY 82901
# 4
# 2
# 1,932
# None
# 0.27 Acres
#
# $210,000
# 1021 Cypress Cir
# Rock Springs, WY 82901
# 4
# 3
# 1,676
# None
# Under 1/2 Acre,
#
# $209,000
# 913 Madison Dr
# Rock Springs, WY 82901
# 3
# 2
# 1,344
# None
# Under 1/2 Acre,
#
# $199,900
# 1344 Teton Street
# Rock Springs, WY 82901
# 3
# 2
# 1,920
# None
# Under 1/2 Acre,
#
# $196,900
# 4 Minnies Lane
# Rock Springs, WY 82901
# 3
# 2
# 1,664
# None
# 2.02 Acres

# %%
#saving to csv: create dict through ea iteration then store those in list
l=[]
for item in all:
    d={}
    d["Price"]=(item.find("h4", {"class":"propPrice"}).text.replace('\n',"").replace(" ",""))
    d["Address"]=(item.find_all("span",{"class":"propAddressCollapse"})[0].text) #1st ele, text
    d["Locality"]=(item.find_all("span",{"class":"propAddressCollapse"})[1].text)
    try:
        d["Beds"]=(item.find("span",{"class":"infoBed"}).find("b").text)
    except:
        d["Beds"]=(None)
    try:
        d["Full Baths"]=(item.find("span",{"class":"infoValueFullBath"}).find("b").text)
    except:
        d["Full Baths"]=(None)
    try:
        d["Area"]=(item.find("span",{"class":"infoSqFt"}).find("b").text)
    except:
        d["Area"]=(None)
    try:
        d["Half Baths"]=(item.find("span",{"class":"infoValueHalfBath"}).find("b").text)
    except:
        d["Half Baths"]=(None)
    for column_group in item.find_all("div",{"class":"columnGroup"}):
        for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}), 
                                               column_group.find_all("span",{"class":"featureName"})):
            if "Lot Size" in feature_group.text:
                d["Lot Size"]=(feature_name.text)
    l.append(d)

# %%
len(l)
l
# Out:
# [{'Price': '$725,000',
#   'Address': '0 Gateway',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': None,
#   'Full Baths': None,
#   'Area': None,
#   'Half Baths': None},
#  {'Price': '$452,900',
#   'Address': '1003 Winchester Blvd.',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '4',
#   'Full Baths': '4',
#   'Area': None,
#   'Half Baths': None,
#   'Lot Size': '0.21 Acres'},
#  {'Price': '$396,900',
#   'Address': '600 Talladega',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '5',
#   'Full Baths': '3',
#   'Area': '3,154',
#   'Half Baths': None},
#  {'Price': '$389,900',
#   'Address': '3239 Spearhead Way',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '4',
#   'Full Baths': '3',
#   'Area': '3,076',
#   'Half Baths': '1',
#   'Lot Size': 'Under 1/2 Acre, '},
#  {'Price': '$254,000',
#   'Address': '522 Emerald Street',
#   'Locality': 'Rock Springs, WY 82901',
#   'Beds': '3',
#   'Full Baths': '3',
#   'Area': '1,172',
#   'Half Baths': None,
# ...

# %%
import pandas
df=pandas.DataFrame(l)
df

df.to_csv("PropertyListings.csv")
